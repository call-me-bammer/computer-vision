# %% [markdown]
# opencv-python cv2.imshow() test

# %%
cd /content/drive/MyDrive/root/learn/computer-vision/colab/computer-vision
# Out:
# /content/drive/MyDrive/root/learn/computer-vision/colab/computer-vision

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
print(cv2.__version__)
img = cv2.imread("yihyun_cho.jpg")
cv2_imshow(img)
# Out:
# 4.6.0
# <PIL.Image.Image image mode=RGB size=810x1440 at 0x7F8B682887F0>
